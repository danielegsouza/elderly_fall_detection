# %% [markdown]
# # Avaliando o desempenho de uma Random Forest para o conjunto de dados SysFall

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from sklearn.preprocessing import StandardScaler
import joblib
from sklearn.ensemble import RandomForestClassifier
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay
import os
from sklearn.svm import SVC
import seaborn as sns

# %% [markdown]
# ### Avaliando o desempenho do modelo para Random Forest sem feature extraction e classes balanceadas

# %%
#Ler o novo dataset sem as features
dataset = pd.read_csv('dataset_balanceado.csv')

# Separa os recursos (X) e o rótulo (y)
X = dataset.iloc[:, :-1] # Todos os dados, exceto o último (que é o rótulo)
y = dataset.iloc[:, -1]   # Última coluna como rótulo

# Divide o dataset em conjuntos de treino e teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# #### Testando com 5 árvores

# %%
# Treinando o modelo para random forest classifier
model_rf = RandomForestClassifier(n_estimators=5, random_state=42)
model_rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=5, random_state=42)

# %%
# Salvar o modelo treinado
joblib.dump(model_rf, 'model_rf_5trees_sem_feature_balanceado.pkl')
# Out:
# ['model_rf_5trees_sem_feature_balanceado.pkl']

# %%
# Testando o modelo a partir do modelo salvo
model_rf = joblib.load('model_rf_5trees_sem_feature_balanceado.pkl')
y_pred_rf = model_rf.predict(X_test)

# Calcula a acurácia, precisão, recall e f1-score
accuracy_rf = accuracy_score(y_test, y_pred_rf)
print(f'Acurácia: {accuracy_rf:.2f}')

precision_rf = precision_score(y_test, y_pred_rf)
print(f'Precisão: {precision_rf:.2f}')

recall_rf = recall_score(y_test, y_pred_rf)
print(f'Recall: {recall_rf:.2f}')

f1_rf = f1_score(y_test, y_pred_rf)
print(f'F1-Score: {f1_rf:.2f}')

# Plotar a matriz de confusão de forma formatada
cm = confusion_matrix(y_test, y_pred_rf)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Sem queda', 'Com queda'])

#Salvando a matriz de confusão como imagem
plt.savefig('matriz_confusao_sem_feature_balanceado.png')

disp.plot()
plt.show()
# Out:
# Acurácia: 0.84
# Precisão: 0.86
# Recall: 0.82
# F1-Score: 0.84

# %% [markdown]
# #### Testando com 10 árvores

# %%
# Treinando o modelo para random forest classifier
model_rf = RandomForestClassifier(n_estimators=10, random_state=42)
model_rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=10, random_state=42)

# %%
# Salvar o modelo treinado
joblib.dump(model_rf, 'model_rf_10trees_sem_feature_balanceado.pkl')
# Out:
# ['model_rf_10trees_sem_feature_balanceado.pkl']

# %%
# Testando o modelo a partir do modelo salvo
model_rf = joblib.load('model_rf_10trees_sem_feature_balanceado.pkl')
y_pred_rf = model_rf.predict(X_test)

# Calcula a acurácia, precisão, recall e f1-score
accuracy_rf = accuracy_score(y_test, y_pred_rf)
print(f'Acurácia: {accuracy_rf:.2f}')

precision_rf = precision_score(y_test, y_pred_rf)
print(f'Precisão: {precision_rf:.2f}')

recall_rf = recall_score(y_test, y_pred_rf)
print(f'Recall: {recall_rf:.2f}')

f1_rf = f1_score(y_test, y_pred_rf)
print(f'F1-Score: {f1_rf:.2f}')

# Plotar a matriz de confusão de forma formatada
cm = confusion_matrix(y_test, y_pred_rf)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Sem queda', 'Com queda'])
disp.plot()
plt.show()
# Out:
# Acurácia: 0.85
# Precisão: 0.90
# Recall: 0.79
# F1-Score: 0.84

# %% [markdown]
# #### Testando com 50 árvores

# %%
# Treinando o modelo para random forest classifier
model_rf = RandomForestClassifier(n_estimators=50, random_state=42)
model_rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=50, random_state=42)

# %%
# Salvar o modelo treinado
joblib.dump(model_rf, 'model_rf_50trees_sem_feature_balanceado.pkl')
# Out:
# ['model_rf_50trees_sem_feature_balanceado.pkl']

# %%
# Testando o modelo a partir do modelo salvo
model_rf = joblib.load('model_rf_50trees_sem_feature_balanceado.pkl')
y_pred_rf = model_rf.predict(X_test)

# Calcula a acurácia, precisão, recall e f1-score
accuracy_rf = accuracy_score(y_test, y_pred_rf)
print(f'Acurácia: {accuracy_rf:.2f}')

precision_rf = precision_score(y_test, y_pred_rf)
print(f'Precisão: {precision_rf:.2f}')

recall_rf = recall_score(y_test, y_pred_rf)
print(f'Recall: {recall_rf:.2f}')

f1_rf = f1_score(y_test, y_pred_rf)
print(f'F1-Score: {f1_rf:.2f}')

# Plotar a matriz de confusão de forma formatada
cm = confusion_matrix(y_test, y_pred_rf)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Sem queda', 'Com queda'])
disp.plot()
plt.show()
# Out:
# Acurácia: 0.87
# Precisão: 0.91
# Recall: 0.82
# F1-Score: 0.86

# %%
# Imprime as metricas obtidas para cada modelos em forma de tabela

data = {'Modelo': ['RF 5 trees', 'RF 10 trees', 'RF 50 trees'],
        'Acurácia': [0.84, 0.85, 0.87],
        'Precisão': [0.86, 0.90, 0.91],
        'Recall': [0.81, 0.79, 0.82],
        'F1-Score': [0.83, 0.84, 0.86]}
df = pd.DataFrame(data)

# Imprime o DataFrame
print(df)
# Out:
#         Modelo  Acurácia  Precisão  Recall  F1-Score
# 0   RF 5 trees      0.84      0.86    0.81      0.83
# 1  RF 10 trees      0.85      0.90    0.79      0.84
# 2  RF 50 trees      0.87      0.91    0.82      0.86

# %% [markdown]
# #### Salvando os coeficientes do modelo escolhido

# %%
# Carrega o modelo escolhido
model_rf = joblib.load('model_rf_5trees_sem_feature_balanceado.pkl')

# Salva os coeficientes do modelo em um arquivo
np.savetxt('coeficientes_classe_balanceada.csv', model_rf.feature_importances_, delimiter=',')

# Carrega os coeficientes do arquivo
coeficientes = np.loadtxt('coeficientes_classe_balanceada.csv', delimiter=',')
print(coeficientes)
# Out:
# [0.1682157  0.25421776 0.17192119 0.14709389 0.13709507 0.1214564 ]

# %%
# Cria um DataFrame com os coeficientes
df_coef = pd.DataFrame({'Variável': dataset.columns[:-1], 'Coeficiente': coeficientes})

# Exibe o DataFrame
sns.barplot(x='Coeficiente', y='Variável', data=df_coef)

# Salva o gráfico como imagem
plt.savefig('graficocoeficientesbalanceados.png', bbox_inches='tight')

# Mostra o gráfico
plt.show()

# %% [markdown]
# ##### Convertendo para código C usando Emlearn

# %%
# Carrega o modelo de random forest com 5 árvores
model_rf = joblib.load('model_rf_5trees_sem_feature_balanceado.pkl')

# %%
from sklearn.ensemble import RandomForestClassifier
estimator = RandomForestClassifier(n_estimators=10, max_depth=10)
estimator.fit(X_train, y_train)
...
# Out:
# Ellipsis

# %%
import emlearn
cmodel = emlearn.convert(estimator, method='inline')
cmodel.save(file='random_forest.h', name='random_forest')
# Out:
# '\n\n\n    // !!! This file is generated using emlearn !!!\n\n    #include <eml_trees.h>\n    \n\nstatic const EmlTreesNode random_forest_nodes[9366] = {\n  { 0, -123.500000f, 1, 446 },\n  { 4, 132.500000f, 1, 227 },\n  { 5, 54.500000f, 1, 122 },\n  { 5, -48.500000f, 1, 59 },\n  { 1, 10.500000f, 1, 32 },\n  { 2, 86.500000f, 1, 16 },\n  { 1, -71.500000f, 1, 8 },\n  { 4, -1931.500000f, 1, 4 },\n  { 4, -3045.500000f, 1, 2 },\n  { 2, -150.000000f, -1, -1 },\n  { 0, -354.500000f, -1, -2 },\n  { 1, -343.500000f, 1, 2 },\n  { 3, 2889.500000f, -2, -2 },\n  { 5, -370.500000f, -2, -2 },\n  { 4, -2148.500000f, 1, 4 },\n  { 4, -2722.000000f, 1, 2 },\n  { 2, -743.500000f, -1, -1 },\n  { 5, -370.000000f, -1, -2 },\n  { 0, -170.500000f, 1, 2 },\n  { 3, 778.500000f, -1, -2 },\n  { 4, -65.500000f, -2, -2 },\n  { 5, -101.500000f, 1, 8 },\n  { 1, -369.500000f, 1, 4 },\n  { 4, -1348.500000f, 1, 2 },\n  { 3, 2211.500000f, -1, -1 },\n  { 2, 435.500000f, -2, -1 },\n  { 3, 101.500000f, 1, 2 },\n  { 2, 144.500000f, -2, -1 },\n  { 1, -70.500000f, -1, -2 },\n  { 0, -215.500000f, 1, 4 },\n  { 3, 150.500000f, 1, 2 },\n  { 2, 105.500000f, -2, -1 },\n  { 2, 803.500000f, -2, -1 },\n  { 3, 193.500000f, 1, 2 },\n  { 4, -365.000000f, -2, -1 },\n  { 1, -62.500000f, -1, -2 },\n  { 1, 34.500000f, 1, 15 },\n  { 1, 17.500000f, 1, 8 },\n  { 4, -52.500000f, 1, 4 },\n  { 5, -516.500000f, 1, 2 },\n  { 3, 983.500000f, -1, -2 },\n  { 0, -239.500000f, -2, -1 },\n  { 3, -71.000000f, 1, 2 },\n  { 4, -27.000000f, -2, -1 },\n  { 2, -328.000000f, -2, -1 },\n  { 3, 357.500000f, 1, 4 },\n  { 2, -303.500000f, 1, 2 },\n  { 0, -341.000000f, -1, -2 },\n  { 5, -62.500000f, -1, -1 },\n  { 4, -1996.000000f, -1, 1 },\n  { 2, -69.500000f, -2, -1 },\n  { 4, -2717.500000f, 1, 4 },\n  { 4, -3455.000000f, -1, 1 },\n  { 5, -891.000000f, -1, 1 },\n  { 1, 99.500000f, -1, -1 },\n  { 2, -14.500000f, 1, 4 },\n  { 3, 1034.000000f, 1, 2 },\n  { 3, -327.500000f, -1, -1 },\n  { 0, -220.500000f, -1, -2 },\n  { 1, 58.500000f, 1, 2 },\n  { 0, -255.500000f, -1, -1 },\n  { 2, 148.500000f, -1, -1 },\n  { 1, 9.500000f, 1, 32 },\n  { 5, 9.500000f, 1, 16 },\n  { 0, -221.500000f, 1, 8 },\n  { 1, -59.500000f, 1, 4 },\n  { 0, -227.500000f, 1, 2 },\n  { 2, 84.000000f, -2, -1 },\n  { 4, 44.500000f, -1, -2 },\n  { 5, -18.500000f, 1, 2 },\n  { 5, -25.500000f, -1, -1 },\n  { 3, -59.500000f, -1, -1 },\n  { 1, -147.500000f, 1, 4 },\n  { 4, -2260.500000f, 1, 2 },\n  { 2, -112.000000f, -2, -1 },\n  { 1, -332.500000f, -2, -2 },\n  { 2, -258.000000f, 1, 2 },\n  { 1, -137.000000f, -1, -2 },\n  { 5, -23.500000f, -1, -1 },\n  { 4, -209.500000f, 1, 8 },\n  { 4, -556.500000f, 1, 4 },\n  { 4, -1858.500000f, 1, 2 },\n  { 4, -2095.500000f, -2, -1 },\n  { 0, -200.500000f, -2, -2 },\n  { 0, -232.500000f, 1, 2 },\n  { 2, -18.500000f, -1, -2 },\n  { 1, -45.500000f, -2, -1 },\n  { 0, -218.500000f, 1, 4 },\n  { 2, -39.500000f, 1, 2 },\n  { 3, -125.000000f, -1, -1 },\n  { 5, 20.500000f, -1, -2 },\n  { 1, -158.500000f, 1, 2 },\n  { 0, -163.500000f, -2, -2 },\n  { 0, -200.500000f, -1, -1 },\n  { 0, -252.500000f, 1, 16 },\n  { 4, -40.500000f, 1, 8 },\n  { 4, -80.500000f, 1, 4 },\n  { 0, -316.500000f, 1, 2 },\n  { 1, 17.000000f, -2, -1 },\n  { 3, -2694.500000f, -2, -1 },\n  { 1, 26.500000f, 1, 2 },\n  { 3, -99.500000f, -2, -1 },\n  { 4, -58.500000f, -1, -1 },\n  { 3, -78.500000f, 1, 4 },\n  { 1, 30.500000f, 1, 2 },\n  { 4, 14.500000f, -1, -1 },\n  { 1, 40.500000f, -1, -1 },\n  { 1, 17.500000f, 1, 2 },\n  { 5, -10.500000f, -1, -1 },\n  { 1, 25.500000f, -1, -1 },\n  { 3, 359.500000f, 1, 8 },\n  { 4, -64.500000f, 1, 4 },\n  { 1, 25.500000f, 1, 2 },\n  { 4, -348.500000f, -2, -1 },\n  { 3, 163.000000f, -1, -1 },\n  { 0, -221.500000f, 1, 2 },\n  { 3, -432.000000f, -2, -1 },\n  { 5, 15.500000f, -1, -1 },\n  { 3, 1940.500000f, 1, 4 },\n  { 4, -126.500000f, 1, 2 },\n  { 2, 55.500000f, -2, -1 },\n  { 5, -34.500000f, -1, -1 },\n  { 1, 37.500000f, -1, 1 },\n  { 4, -111.500000f, -2, -1 },\n  { 1, 5.500000f, 1, 60 },\n  { 5, 2094.500000f, 1, 32 },\n  { 2, 1 ...

# %% [markdown]
# ##### Convertendo para código C usando micromlgen

# %%
from micromlgen import port

with open('RandomForestRegressor.h', 'w') as file:
        file.write(port(estimator))
